# %% [markdown]
# <a href="https://colab.research.google.com/github/suphichchakhasingh75-debug/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # สุพิชชา คำสิงห์

# %%
print('ID673020265-5')
# Out:
# ID673020265-5
